# %% [markdown]
# # Modelo de reinforcement learning no CartPole-v1

# %% [markdown]
# ## Importando gymnasium(Gym) e Stable Baselines3

# %%
import gymnasium as gym
from stable_baselines3 import A2C
# Out:
# WARNING:tensorflow:From C:\Users\julio\anaconda3\envs\area_de_estudos\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %% [markdown]
# ## Importando o ambiente virtual cartpole-1
# - O objetivo do jogo é equilibrar o carrinho usando a alavanca

# %%
env = gym.make("CartPole-v1", render_mode="rgb_array")

# %% [markdown]
# ## Criando o agente e treinando por 1.000.000 de vezes

# %%
model = A2C("MlpPolicy", env, verbose=1)
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %%
model.learn(total_timesteps=1_000_000)
# Out:
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 20.6     |
# |    ep_rew_mean        | 20.6     |
# | time/                 |          |
# |    fps                | 278      |
# |    iterations         | 100      |
# |    time_elapsed       | 1        |
# |    total_timesteps    | 500      |
# | train/                |          |
# |    entropy_loss       | -0.693   |
# |    explained_variance | 0.013    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 99       |
# |    policy_loss        | -4.03    |
# |    value_loss         | 34.9     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 21.6     |
# |    ep_rew_mean        | 21.6     |
# | time/                 |          |
# |    fps                | 284      |
# |    iterations         | 200      |
# |    time_elapsed       | 3        |
# ...

# %% [markdown]
# ## Vectorizando o ambiente

# %%
vec_env = model.get_env()

# %% [markdown]
# ## Observando o Agente depois de treinar

# %%
obs = vec_env.reset()
for i in range(1000):
    action, _state = model.predict(obs, deterministic=True)
    obs, reward, done, info = vec_env.step(action)
    vec_env.render("human")
